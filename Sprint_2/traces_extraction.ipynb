# %%
import pm4py
import os 
import pandas as pd

# CHANGE THE PATH TO YOU DATA FODER WITH ORIGINAL DATA - XES.GZ
path_to_data_foder = '/Users/alexraudvee/Desktop/TU_e/year_2/Q3Y2_Process_Mining/process_mining_data'

# HERE YOU HAVE TO CHOOSE THE DATASET WITH WHICH YOU WANNA WORK "BPI_Challenge_2012" OR "BPI_Challenge_2017"
chosed_dataset = 'BPI_Challenge_2017'

# %%
if __name__ == '__main__':
    dataframe_train = pd.read_csv(f'../data/{chosed_dataset}.csv')

    dataframe_train = pm4py.format_dataframe(dataframe_train, case_id='case:concept:name', activity_key='concept:name', timestamp_key='time:timestamp')

    event_log_train = pm4py.convert_to_event_log(dataframe_train)
     
    pm4py.write_xes(event_log_train, f'../data/event_log_{chosed_dataset}.xes')
 
    event_logs_files_names = [f'event_log_{chosed_dataset}']
# Out:
# /Users/alexraudvee/Desktop/TU_e/year_2/Q3Y2_Process_Mining/Process_Mining_1/.venv/lib/python3.10/site-packages/pm4py/utils.py:536: UserWarning: the EventLog class has been deprecated and will be removed in a future release.
#   warnings.warn("the EventLog class has been deprecated and will be removed in a future release.")
# exporting log, completed traces :: 100%|██████████| 31509/31509 [01:30<00:00, 348.76it/s]

# %%
for event_log_file in event_logs_files_names:

    log = pm4py.read_xes(os.path.join(f"../data/{event_log_file}.xes"))
    log = pm4py.convert_to_event_log(log)

    trace_df_list = []
    for trace in log:
        case_concept_name = trace.attributes['concept:name']
        concept_name_col = []
        timestamp_col = []
        
        for event in trace:
            concept_name_col.append(event['concept:name'])
            timestamp_col.append(event['time:timestamp'])
        
        df_trace = pd.DataFrame({'concept:name': concept_name_col, 'time:timestamp': timestamp_col})
        df_trace = pd.concat([df_trace, pd.DataFrame({'concept:name': ['END'], 'time:timestamp': [timestamp_col[-1]]})], ignore_index=True)
        df_trace.name = f'{case_concept_name}'

        trace_df_list.append(df_trace)

    df_final = pd.DataFrame({'case:concept:name': [df.name for df in trace_df_list], 'trace': trace_df_list})

    df_final.to_json(f'../data/traces_{event_log_file}.json')

    if os.path.exists(f'../data/{event_log_file}.xes'):
        # Remove the file
        os.remove(f'../data/{event_log_file}.xes')
    
df_final
# Out:
# parsing log, completed traces ::  59%|█████▊    | 18437/31509 [04:00<00:46, 283.14it/s]<bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x1115c9870>>
# Traceback (most recent call last):
#   File "/Users/alexraudvee/Desktop/TU_e/year_2/Q3Y2_Process_Mining/Process_Mining_1/.venv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 770, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# parsing log, completed traces :: 100%|██████████| 31509/31509 [04:44<00:00, 110.69it/s]

# %%
case_concept_name
# Out:
# 'Application_999993812'

# %% [markdown]
# ### So the final dataframe which is converted in csv is the dataframe with dataframes for each case:concept:name where inner dataframe is associated with unique case:concept:name

# %%
df_final['trace'].loc[0]
# Out:
#               concept:name                   time:timestamp
# 0              A_SUBMITTED 2011-10-01 00:38:44.546000+00:00
# 1        A_PARTLYSUBMITTED 2011-10-01 00:38:44.880000+00:00
# 2            A_PREACCEPTED 2011-10-01 00:39:37.906000+00:00
# 3   W_Completeren aanvraag 2011-10-01 00:39:38.875000+00:00
# 4   W_Completeren aanvraag 2011-10-01 11:36:46.437000+00:00
# 5               A_ACCEPTED 2011-10-01 11:42:43.308000+00:00
# 6               O_SELECTED 2011-10-01 11:45:09.243000+00:00
# 7              A_FINALIZED 2011-10-01 11:45:09.243000+00:00
# 8                O_CREATED 2011-10-01 11:45:11.197000+00:00
# 9                   O_SENT 2011-10-01 11:45:11.380000+00:00
# 10     W_Nabellen offertes 2011-10-01 11:45:11.554000+00:00
# 11  W_Completeren aanvraag 2011-10-01 11:45:13.917000+00:00
# 12     W_Nabellen offertes 2011-10-01 12:15:41.290000+00:00
# 13     W_Nabellen offertes 2011-10-01 12:17:08.924000+00:00
# 14     W_Nabellen offertes 2011-10-08 16:26:57.720000+00:00
# 15     W_Nabellen offertes 2011-10-08 16:32:00.886000+00:00
# 16     W_Nabellen offertes 2011-10-10 11:32:22.495000+00:00
# 17             O_SENT_BACK 2011-10-10 11:33:03.668000+00:00
# 18    W_Valideren aanvraag 2011-10-10 11:33:04.560000+00:00
# 19     W_Nabellen offertes 2011-10-10 11:33:05.791000+00:00
# 20    W_Valideren aanvraag 2011-10-13 10:05:26.925000+00:00
# 21            A_REGISTERED 2011-10-13 10:37:29.226000+00:00
# 22              A_APPROVED 2011-10-13 10:37:29.226000+00:00
# 23              O_ACCEPTED 2011-10-13 10:37:29.226000+00:00
# 24             A_ACTIVATED 2011-10-13 10:37:29.226000+00:00
# 25    W_Valideren aanvraag 2011-10-13 10:37:37.026000+00:00
# 26                     END 2011-10-13 10:37:37.026000+00:00
